# %%
import nltk
nltk.download('wordnet')
from nltk.stem import WordNetLemmatizer
lemmatizer=WordNetLemmatizer()
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\piyushdu\AppData\Roaming\nltk_data...

# %%
lemmatizer.lemmatize("going")
# Out:
# 'going'

# %%
words=["going", "working", "work", "leaving", "leaved"]
for word in words:
    print(word+ "---->" +lemmatizer.lemmatize(word, pos="v"))

print("*************lemmatinization based on the noun***********")
for word in words:
    print(word+ "---->" +lemmatizer.lemmatize(word, pos="n"))
# Out:
# going---->go
# working---->work
# work---->work
# leaving---->leave
# leaved---->leave
# *************lemmatinization based on the noun***********
# going---->going
# working---->working
# work---->work
# leaving---->leaving
# leaved---->leaved
